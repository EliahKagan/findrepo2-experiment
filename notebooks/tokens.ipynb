# %% [markdown]
# # Repo names’ cl100k_base tokens
#
# SPDX-License-Identifier: 0BSD
#
# Each repository name’s tokens are visualized below by highlighting in
# alternating colors.
#
# (They are a snapshot of names from one of my systems that uses
# [newrepo-findrepo](https://github.com/EliahKagan/newrepo-findrepo).)
#
# NOTE: The highlighting *may* look better in VS Code than in JupyterLab.

# %%
import fr2ex

# %%
names = fr2ex.remote.fetch_repo_names()
fr2ex.tokens.show(names)
# Out:
# ..t.
# 18845-repro
# 311calldepth
# ATLProject1
# Adapter
# Alias
# AllBehavior
# AltTreeMap
# AltTreeMap-gist
# AnimalShelterCs
# App1
# AsIs
# AsyncText
# AvaloniaApplication1
# AvaloniaGraphControl
# Bashful
# BeginInvoke
# Benchmark
# Bind
# BlazorSln
# Block
# Boats
# CILSimple
# CILTry
# CILTutorial1
# CMakeProject1
# CMakeSomethingElse
# Calculator
# CallerInformationAttributes
# CancelQuery
# Carto
# CheckDefs
# CheckPermutation
# Chrono
# Co
# CodeFenceCleanup
# CodeFenceCleanup-gist
# CodeFenceCleanup-old-gist
# Collatz
# CompilationFirewalls
# Components
# Concepts0
# Concepts1
# Concepts2
# Concepts3
# ConditionalEntrypoint
# ConfSln
# Conflicts
# ConsoleApp1
# ConsoleApplication1
# ConsoleColorLayer
# Const
# ConstexprIf
# CounterExample
# Covariance
# Cpp20
# Cs7
# Cs7Fr
# Cs8
# Cs8FizzBuzz
# Cs9
# CsWin32Sandbox
# CustomDeleter
# DFS
# Dec
# Declarations
# Declare
# Decorators
# DeductionGuides
# DefensiveCopies
# Delegation
# DeleteMiddleNode
# DeletoTheClown
# ...
